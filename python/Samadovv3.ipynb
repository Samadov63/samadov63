# %%
import  pandas as pd 
data = pd.read_csv("C:/Users/User/Desktop/country_vaccinations.csv" )

# %%
import sqlite3 as s 
con = s.connect("CovidVacc.db")
cur = con.cursor()

# %%
# data.to_sql("vaccinations", con)

# %%
sql = '''create table if not exists countries(id integer primary key, country varchar(120), iso_code varchar(5))'''

# %%
print("Table created!") if (cur.execute(sql)) else print("Something wrong..?")
# Out:
# Table created!

# %%
sqlin = '''insert into countries(country, iso_code) select distinct country, iso_code from vaccinations  
'''

# %%
res  = cur.execute(sqlin)

# %%
show = "select * from countries"
res = cur.execute(show)
print(res.fetchall())
# Out:
# [(1, 'Afghanistan', 'AFG'), (2, 'Albania', 'ALB'), (3, 'Algeria', 'DZA'), (4, 'Andorra', 'AND'), (5, 'Angola', 'AGO'), (6, 'Anguilla', 'AIA'), (7, 'Antigua and Barbuda', 'ATG'), (8, 'Argentina', 'ARG'), (9, 'Armenia', 'ARM'), (10, 'Aruba', 'ABW'), (11, 'Australia', 'AUS'), (12, 'Austria', 'AUT'), (13, 'Azerbaijan', 'AZE'), (14, 'Bahamas', 'BHS'), (15, 'Bahrain', 'BHR'), (16, 'Bangladesh', 'BGD'), (17, 'Barbados', 'BRB'), (18, 'Belarus', 'BLR'), (19, 'Belgium', 'BEL'), (20, 'Belize', 'BLZ'), (21, 'Bermuda', 'BMU'), (22, 'Bhutan', 'BTN'), (23, 'Bolivia', 'BOL'), (24, 'Bosnia and Herzegovina', 'BIH'), (25, 'Botswana', 'BWA'), (26, 'Brazil', 'BRA'), (27, 'Brunei', 'BRN'), (28, 'Bulgaria', 'BGR'), (29, 'Cambodia', 'KHM'), (30, 'Cameroon', 'CMR'), (31, 'Canada', 'CAN'), (32, 'Cape Verde', 'CPV'), (33, 'Cayman Islands', 'CYM'), (34, 'Chile', 'CHL'), (35, 'China', 'CHN'), (36, 'Colombia', 'COL'), (37, 'Congo', 'COG'), (38, 'Costa Rica', 'CRI'), (39, "Cote d'Ivoire", 'CIV'), (40, 'Croatia', '
# ...

# %%
sql = '''create table if not exists vaccine(id integer primary key, name varchar(70), 
source_name varchar(200), source_website text) 
'''

# %%
print("Table created!") if(cur.execute(sql)) else print("Something wrong..?")
# Out:
# Table created!

# %%
vaccine = '''insert into vaccine(name, source_name, source_website) select distinct 
vaccines, source_name, source_website from vaccinations'''

a = cur.execute(vaccine)

a = 'select name, source_name from vaccine'
a = cur.execute(a)
print(cur.fetchall())
# Out:
# [('Oxford/AstraZeneca', 'Government of Afghanistan'), ('Pfizer/BioNTech, Sinovac', 'Ministry of Health'), ('Sputnik V', 'Ministry of Health'), ('Oxford/AstraZeneca, Pfizer/BioNTech', 'Government of Andorra'), ('Oxford/AstraZeneca', 'Ministry of Health'), ('Oxford/AstraZeneca', 'Ministry of Health'), ('Oxford/AstraZeneca', 'Ministry of Health'), ('Oxford/AstraZeneca, Sinopharm/Beijing, Sputnik V', 'Ministry of Health'), ('Sputnik V', 'Ministry of Health'), ('Pfizer/BioNTech', 'Government of Aruba'), ('Oxford/AstraZeneca, Pfizer/BioNTech', 'Government of Australia via covidlive.com.au'), ('Moderna, Oxford/AstraZeneca, Pfizer/BioNTech', 'Ministry of Health'), ('Sinovac', 'Government of Azerbaijan'), ('Oxford/AstraZeneca', 'Government of the Bahamas'), ('Oxford/AstraZeneca, Pfizer/BioNTech, Sinopharm/Beijing, Sputnik V', 'Ministry of Health'), ('Oxford/AstraZeneca', 'Directorate General of Health Services'), ('Oxford/AstraZeneca', 'Ministry of Health'), ('Sputnik V', 'Ministry of Health'
# ...

# %%
sql = '''create table vaccination(id integer primary key, idcountry integer, date date, total_vaccinations float )'''

# %%
vaccination = '''insert into vaccination(idcountry, date , total_vaccinations, people_vaccinated, daily_vaccination, idvac)
select (select c.id from countries c, vaccinations v where c.country =v.country) as  idcountry, date, total_vaccinations, 
people_vaccinated, daily_vaccinations as  daily_vaccination, (select v.id from vaccine v, vaccinations vs where v.name=vs.vaccines
) as idvac from vaccinations'''

res = cur.execute(vaccination)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# <ipython-input-100-3fe252619f77> in <module>
#       4 ) as idvac from vaccinations'''
#       5
# ----> 6 res = cur.execute(vaccination)
#
# OperationalError: no such table: vaccination

# %%
cur.execute("select * from vaccinations")
print(cur.fetchall())
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
cur.execute("select * from vaccinations")
print(cur.fetchall())
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
