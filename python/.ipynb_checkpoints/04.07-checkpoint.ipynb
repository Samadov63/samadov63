# %%
import pandas as pd 
import numpy as np
df = pd.read_excel(r'C:\Users\HP\Desktop\csv\trips_data.xlsx')
df.head()
# Out:
#    salary          city  age vacation_preference transport_preference  \
# 0  196000     Краснодар   25             Шоппинг           Автомобиль
# 1  152000  Екатеринбург   60         Архитектура              Самолет
# 2   83000         Томск   49         Архитектура           Автомобиль
# 3  161000     Краснодар   41             Шоппинг           Автомобиль
# 4  146000     Краснодар   58         Архитектура              Самолет
#
#    family_members    target
# 0               1  New York
# 1               1    London
# 2               2    Sydney
# 3               0  New York
# 4               1    Sydney

# %%
df[df.city.isna()]
# Out:
# Empty DataFrame
# Columns: [salary, city, age, vacation_preference, transport_preference, family_members, target]
# Index: []

# %%
df.columns
# Out:
# Index(['salary', 'city', 'age', 'vacation_preference', 'transport_preference',
#        'family_members', 'target'],
#       dtype='object')

# %%
df.dropna(df, rows = ['London'], axis = 0)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-161-8dad4d4b0f93> in <module>
# ----> 1 df.dropna(df, rows = ['London'], axis = 0)
#
# TypeError: dropna() got an unexpected keyword argument 'rows'

# %%
df1 = pd.get_dummies(df, columns = ['city', 'vacation_preference', 'transport_preference'])

# %%
df1
# Out:
#      salary  age  family_members    target  city_Екатеринбург  city_Киев  \
# 0    196000   25               1  New York                  0          0
# 1    152000   60               1    London                  1          0
# 2     83000   49               2    Sydney                  0          0
# 3    161000   41               0  New York                  0          0
# 4    146000   58               1    Sydney                  0          0
# ..      ...  ...             ...       ...                ...        ...
# 995   81000   55               2     Paris                  0          0
# 996   96000   32               1     Paris                  0          0
# 997   56000   68               2     Paris                  0          0
# 998  162000   69               0    Sydney                  0          0
# 999  171000   35               1  New York                  0          0
#
#      city_Краснодар  city_Минск  city_Москва  city_Новосибирск  ...  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 7 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   salary                1000 non-null   int64
#  1   city                  1000 non-null   object
#  2   age                   1000 non-null   int64
#  3   vacation_preference   1000 non-null   object
#  4   transport_preference  1000 non-null   object
#  5   family_members        1000 non-null   int64
#  6   target                1000 non-null   object
# dtypes: int64(3), object(4)
# memory usage: 54.8+ KB

# %%
y = df1['target'].copy() 
X = df1.drop('target', axis=1).copy()

# %%
X.columns
# Out:
# Index(['salary', 'age', 'family_members', 'city_Екатеринбург', 'city_Киев',
#        'city_Краснодар', 'city_Минск', 'city_Москва', 'city_Новосибирск',
#        'city_Омск', 'city_Петербург', 'city_Томск', 'city_Хабаровск',
#        'city_Ярославль', 'vacation_preference_Архитектура',
#        'vacation_preference_Ночные клубы', 'vacation_preference_Пляжный отдых',
#        'vacation_preference_Шоппинг', 'transport_preference_Автомобиль',
#        'transport_preference_Космический корабль',
#        'transport_preference_Морской транспорт', 'transport_preference_Поезд',
#        'transport_preference_Самолет'],
#       dtype='object')

# %%
y.shape
# Out:
# (1000,)

# %%
y.columns
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-157-e86f16c43c0e> in <module>
# ----> 1 y.columns
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5137             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5138                 return self[name]
# -> 5139             return object.__getattribute__(self, name)
#    5140
#    5141     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'columns'

# %%
from sklearn.model_selection import train_test_split

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.33, random_state = 0)

# %%
from sklearn.metrics import classification_report,confusion_matrix

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
df['city'].map({'Томск':1,'Краснодар':2})
# Out:
# 0      2.0
# 1      NaN
# 2      1.0
# 3      2.0
# 4      2.0
#       ...
# 995    2.0
# 996    2.0
# 997    2.0
# 998    2.0
# 999    2.0
# Name: city, Length: 1000, dtype: float64

# %%
rfc.fit(X_train,y_train)
# Out:
# RandomForestClassifier()

# %%
predictions = rfc.predict(X_test)

# %%
print(classification_report(y_test, predictions))
# Out:
#               precision    recall  f1-score   support
#
#       London       0.81      0.89      0.84        61
#     New York       0.93      0.87      0.90        79
#        Paris       0.82      0.94      0.87        62
#       Sydney       0.92      0.84      0.88        73
#        Tokio       0.90      0.85      0.88        55
#
#     accuracy                           0.88       330
#    macro avg       0.88      0.88      0.87       330
# weighted avg       0.88      0.88      0.88       330

# %%
print(confusion_matrix(y_test,predictions))
# Out:
# [[54  0  4  1  2]
#  [ 4 69  2  3  1]
#  [ 0  1 58  1  2]
#  [ 6  4  2 61  0]
#  [ 3  0  5  0 47]]

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dtree = DecisionTreeClassifier()

# %%
dtree.fit(X_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-120-97e56a26e4dc> in <module>
# ----> 1 dtree.fit(X_train,y_train)
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\tree\_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     888         """
#     889
# --> 890         super().fit(
#     891             X, y,
#     892             sample_weight=sample_weight,
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\tree\_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     154             check_X_params = dict(dtype=DTYPE, accept_sparse="csc")
#     155             check_y_params = dict(ensure_2d=False, dtype=None)
# --> 156             X, y = self._validate_data(X, y,
#     157                                        validate_separately=(check_X_params,
# ...

# %%
predictions = dtree.predict(X_test)

# %%
print(classification_report(y_test,predictions))
# Out:
#               precision    recall  f1-score   support
#
#       Bronze       0.61      0.61      0.61       619
#         Gold       0.64      0.64      0.64       636
#       Silver       0.60      0.60      0.60       650
#
#     accuracy                           0.62      1905
#    macro avg       0.62      0.62      0.62      1905
# weighted avg       0.62      0.62      0.62      1905

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
model = RandomForestClassifier()
model.fit(X,y)
# Out:
# RandomForestClassifier()

# %%
{ col:[0] for col in X.columns}
# Out:
# {'Year': [0],
#  'City_Albertville': [0],
#  'City_Calgary': [0],
#  'City_Chamonix': [0],
#  "City_Cortina d'Ampezzo": [0],
#  'City_Garmisch Partenkirchen': [0],
#  'City_Grenoble': [0],
#  'City_Innsbruck': [0],
#  'City_Lake Placid': [0],
#  'City_Lillehammer': [0],
#  'City_Nagano': [0],
#  'City_Oslo': [0],
#  'City_Salt Lake City': [0],
#  'City_Sapporo': [0],
#  'City_Sarajevo': [0],
#  'City_Sochi': [0],
#  'City_Squaw Valley': [0],
#  'City_St.Moritz': [0],
#  'City_Turin': [0],
#  'City_Vancouver': [0],
#  'Sport_Biathlon': [0],
#  'Sport_Bobsleigh': [0],
#  'Sport_Curling': [0],
#  'Sport_Ice Hockey': [0],
#  'Sport_Luge': [0],
#  'Sport_Skating': [0],
#  'Sport_Skiing': [0],
#  'Discipline_Alpine Skiing': [0],
#  'Discipline_Biathlon': [0],
#  'Discipline_Bobsleigh': [0],
#  'Discipline_Cross Country Skiing': [0],
#  'Discipline_Curling': [0],
#  'Discipline_Figure skating': [0],
#  'Discipline_Freestyle Skiing': [0],
#  'Discipline_Ice Hockey': [0],
# ...

# %%
example = {'Year': [36],
 'City_Albertville': [2],
 'City_Calgary': [2],
 'City_Chamonix': [0],
 "City_Cortina d'Ampezzo": [0],
 'City_Garmisch Partenkirchen': [0],
 'City_Grenoble': [0],
 'City_Innsbruck': [0],
 'City_Lake Placid': [0],
 'City_Lillehammer': [0],
 'City_Nagano': [0],
 'City_Oslo': [0],
 'City_Salt Lake City': [0],
 'City_Sapporo': [0],
 'City_Sarajevo': [0],
 'City_Sochi': [0],
 'City_Squaw Valley': [0],
 'City_St.Moritz': [1],
 'City_Turin': [0],
 'City_Vancouver': [0],
 'Sport_Biathlon': [0],
 'Sport_Bobsleigh': [0],
 'Sport_Curling': [0],
 'Sport_Ice Hockey': [0],
 'Sport_Luge': [0],
 'Sport_Skating': [0],
 'Sport_Skiing': [0],
 'Discipline_Alpine Skiing': [0],
 'Discipline_Biathlon': [0],
 'Discipline_Bobsleigh': [0],
 'Discipline_Cross Country Skiing': [0],
 'Discipline_Curling': [0],
 'Discipline_Figure skating': [0],
 'Discipline_Freestyle Skiing': [0],
 'Discipline_Ice Hockey': [0],
 'Discipline_Luge': [0],
 'Discipline_Nordic Combined': [0],
 'Discipline_Short Track Speed Skating': [0],
 'Discipline_Skeleton': [0],
 'Discipline_Ski Jumping': [1],
 'Discipline_Snowboard': [0],
 'Discipline_Speed skating': [0],
 'Athlete_AAHLBERG, Mats': [0],
 'Athlete_AAHLEN, Thomas': [0],
 'Athlete_AALAND, Per Knut': [0],
 'Athlete_AALTONEN, Juhamatti': [0],
 'Athlete_AAMODT, Kjetil Andre': [0],
 'Athlete_AAS, Roald': [0]}

# %%
example_df = pd.DataFrame(example)
example_df
# Out:
#    Year  City_Albertville  City_Calgary  City_Chamonix  \
# 0    36                 0             0              0
#
#    City_Cortina d'Ampezzo  City_Garmisch Partenkirchen  City_Grenoble  \
# 0                       0                            0              0
#
#    City_Innsbruck  City_Lake Placid  City_Lillehammer  ...  \
# 0               0                 0                 0  ...
#
#    Discipline_Skeleton  Discipline_Ski Jumping  Discipline_Snowboard  \
# 0                    0                       1                     0
#
#    Discipline_Speed skating  Athlete_AAHLBERG, Mats  Athlete_AAHLEN, Thomas  \
# 0                         0                       0                       0
#
#    Athlete_AALAND, Per Knut  Athlete_AALTONEN, Juhamatti  \
# 0                         0                            0
#
#    Athlete_AAMODT, Kjetil Andre  Athlete_AAS, Roald
# 0                             0                   0
#
# [1 rows x 48 columns]

# %%
model.predict(example_df)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-66-17633a7106d1> in <module>
# ----> 1 model.predict(example_df)
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\_forest.py in predict(self, X)
#     627             The predicted classes.
#     628         """
# --> 629         proba = self.predict_proba(X)
#     630
#     631         if self.n_outputs_ == 1:
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\_forest.py in predict_proba(self, X)
#     671         check_is_fitted(self)
#     672         # Check data
# --> 673         X = self._validate_X_predict(X)
#     674
#     675         # Assign chunk of trees to jobs
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\_forest.py in _validate_X_predict(self, X)
#     419         check_is_fitted(self)
#     420
# ...

# %%
pd.read_csv(r'C:\Users\HP\Desktop\csv\CAvideos.csv')
# Out:
#           video_id trending_date  \
# 0      n1WpP7iowLc      17.14.11
# 1      0dBIkQ4Mz1M      17.14.11
# 2      5qpjK5DgCt4      17.14.11
# 3      d380meD0W0M      17.14.11
# 4      2Vv-BfVoq4g      17.14.11
# ...            ...           ...
# 40876  sGolxsMSGfQ      18.14.06
# 40877  8HNuRNi8t70      18.14.06
# 40878  GWlKEM3m2EE      18.14.06
# 40879  lbMKLzQ4cNQ      18.14.06
# 40880  POTgw38-m58      18.14.06
#
#                                                    title     channel_title  \
# 0             Eminem - Walk On Water (Audio) ft. Beyoncé        EminemVEVO
# 1                          PLUSH - Bad Unboxing Fan Mail         iDubbbzTV
# 2      Racist Superman | Rudy Mancuso, King Bach & Le...      Rudy Mancuso
# 3                               I Dare You: GOING BALD!?          nigahiga
# 4            Ed Sheeran - Perfect (Official Music Video)        Ed Sheeran
# ...                                                  ...               ...
# ...

# %%
df.columns
# Out:
# Index(['Year', 'City', 'Sport', 'Discipline', 'Athlete', 'Country', 'Gender',
#        'Event', 'Medal'],
#       dtype='object')

# %%
df[df['City'] == 'Innsbruck']
# Out:
#       Year       City      Sport   Discipline                 Athlete Country  \
# 1004  1964  Innsbruck   Biathlon     Biathlon            JORDET, Olav     NOR
# 1005  1964  Innsbruck   Biathlon     Biathlon       MELANIN, Vladimir     URS
# 1006  1964  Innsbruck   Biathlon     Biathlon     PRIVALOV, Aleksandr     URS
# 1007  1964  Innsbruck  Bobsleigh    Bobsleigh          MONTI, Eugenio     ITA
# 1008  1964  Innsbruck  Bobsleigh    Bobsleigh          RIGONI, Benito     ITA
# ...    ...        ...        ...          ...                     ...     ...
# 1793  1976  Innsbruck     Skiing  Ski Jumping           SCHNABL, Karl     AUT
# 1794  1976  Innsbruck     Skiing  Ski Jumping          INNAUER, Anton     AUT
# 1795  1976  Innsbruck     Skiing  Ski Jumping           SCHNABL, Karl     AUT
# 1796  1976  Innsbruck     Skiing  Ski Jumping  ASCHENBACH, Hans-Georg     GDR
# 1797  1976  Innsbruck     Skiing  Ski Jumping       DANNEBERG, Jochen     GDR
#
# ...

# %%
df.columns
# Out:
# Index(['salary', 'city', 'age', 'vacation_preference', 'transport_preference',
#        'family_members', 'target'],
#       dtype='object')

# %%
df.head()
# Out:
#    salary          city  age vacation_preference transport_preference  \
# 0  196000     Краснодар   25             Шоппинг           Автомобиль
# 1  152000  Екатеринбург   60         Архитектура              Самолет
# 2   83000         Томск   49         Архитектура           Автомобиль
# 3  161000     Краснодар   41             Шоппинг           Автомобиль
# 4  146000     Краснодар   58         Архитектура              Самолет
#
#    family_members    target
# 0               1  New York
# 1               1    London
# 2               2    Sydney
# 3               0  New York
# 4               1    Sydney

# %%
import seaborn as sns
cols = ['salary', 'city', 'age', 'family_members', 'target']
hm = sns.heatmap(df[cols].corr(),
                 cbar=True,
                 annot=True)

# %%
dddd = pd.read_csv(r'C:\Users\HP\Desktop\csv\CAvideos.csv')
dddd.head()
# Out:
#       video_id trending_date  \
# 0  n1WpP7iowLc      17.14.11
# 1  0dBIkQ4Mz1M      17.14.11
# 2  5qpjK5DgCt4      17.14.11
# 3  d380meD0W0M      17.14.11
# 4  2Vv-BfVoq4g      17.14.11
#
#                                                title channel_title  \
# 0         Eminem - Walk On Water (Audio) ft. Beyoncé    EminemVEVO
# 1                      PLUSH - Bad Unboxing Fan Mail     iDubbbzTV
# 2  Racist Superman | Rudy Mancuso, King Bach & Le...  Rudy Mancuso
# 3                           I Dare You: GOING BALD!?      nigahiga
# 4        Ed Sheeran - Perfect (Official Music Video)    Ed Sheeran
#
#    category_id              publish_time  \
# 0           10  2017-11-10T17:00:03.000Z
# 1           23  2017-11-13T17:00:00.000Z
# 2           23  2017-11-12T19:05:24.000Z
# 3           24  2017-11-12T18:01:41.000Z
# 4           10  2017-11-09T11:04:14.000Z
#
#                                                 tags     views    likes  \
# ...

# %%
import seaborn as sns
cols = ['category_id', 'dislikes']
hm = sns.heatmap(dddd[cols].corr(),
                 cbar=True,
                 annot=True)

# %%
X = dddd[['likes']].values
y = dddd['views'].values

# %%
from sklearn.linear_model import LinearRegression
slr = LinearRegression()
slr.fit(X, y)
y_pred = slr.predict(X)
print('b: {:.2f}'.format(slr.coef_[0]))
print('a: {:.2f}'.format(slr.intercept_))
# Out:
# b: 21.18
# a: 308501.12

# %%
import matplotlib.pyplot as plt
plt.scatter(X, y)
plt.plot(X, slr.predict(X), color='red', linewidth=2);
