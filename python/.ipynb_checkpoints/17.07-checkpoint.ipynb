# %%
import pandas as pd
df = pd.read_csv(r'C:\Users\HP\Desktop\sales_train.csv')

# %%
df.head()
# Out:
#          date  date_block_num  shop_id  item_id  item_price  item_cnt_day
# 0  02.01.2013               0       59    22154      999.00           1.0
# 1  03.01.2013               0       25     2552      899.00           1.0
# 2  05.01.2013               0       25     2552      899.00          -1.0
# 3  06.01.2013               0       25     2554     1709.05           1.0
# 4  15.01.2013               0       25     2555     1099.00           1.0

# %%
df[(df['shop_id'] == 10)].to_excel('10.xlsx', index = False)

# %%
df.groupby('item_cnt_day').agg({'item_cnt_day': 'count'})
# Out:
#               item_cnt_day
# item_cnt_day
# -22.0                    1
# -16.0                    1
# -9.0                     1
# -6.0                     2
# -5.0                     4
# ...                    ...
#  624.0                   1
#  637.0                   1
#  669.0                   1
#  1000.0                  1
#  2169.0                  1
#
# [198 rows x 1 columns]

# %%
df.shape
# Out:
# (2935849, 6)

# %%
df.shape
# Out:
# (2935849, 6)

# %%
arr = df.sample(frac=0.01, replace=True, random_state=1)
arr = pd.DataFrame(arr)
arr.to_csv('file.csv')
data = pd.read_csv('file.csv')
data.head()
data.shape
data.drop('date', axis=1, inplace=True)

# %%
data.drop('Unnamed: 0', axis=1, inplace=True)

# %%
X=data.drop('item_cnt_day', axis=1)
y = data['item_cnt_day']
from sklearn.ensemble import RandomForestClassifier

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)
rfc=RandomForestClassifier().fit(X_train,y_train)
rfc.score(X_test,y_test)
# Out:
# 0.8933923705722071

# %%
data.head()
data.shape
# Out:
# (29358, 5)

# %%
data.head()
# Out:
#    date_block_num  shop_id  item_id  item_price  item_cnt_day
# 0               1       42    11919       149.0           1.0
# 1               4       50    17822       349.0           2.0
# 2              27       22     6789       498.0           1.0
# 3               4       54    11496       399.0           3.0
# 4               7       10    19415       399.0           1.0

# %%
# rfc.predict([[4, 50, 17822, 349.0]])


datas = data.drop('item_cnt_day', axis=1)

# %%
# from sklearn.linear_model import LogisticRegression
# from sklearn.naive_bayes import GaussianNB
# from sklearn.svm import SVC
# from sklearn.ensemble import VotingClassifier
# model1 = LogisticRegression(random_state=1, solver='newton-cg')
# model2 = DecisionTreeClassifier(random_state=1)
# model3=GaussianNB()
# model4=SVC()
# model = VotingClassifier(estimators=[('lr', model1), ('dt', model2),('gnb',model3),('svc', model4)], voting='hard')
# model.fit(X_train,y_train)
# model.score(X_test,y_test)

# %%
# rfc.predict()
import numpy as np
arr = np.array(datas)

# %%
arr[1]
# Out:
# array([4.0000e+00, 5.0000e+01, 1.7822e+04, 3.4900e+02])

# %%
rfc.predict(arr[[3]])
# Out:
# array([3.])

# %%
c = 0
for i in arr:
    print('id=', i[0], 'price', i[-1], rfc.predict([i]), '$ ','та мефурушад')
    c += 1
    if c == 100:
        break
# Out:
# id= 1.0 price 149.0 [1.] $  та мефурушад
# id= 4.0 price 349.0 [2.] $  та мефурушад
# id= 27.0 price 498.0 [1.] $  та мефурушад
# id= 4.0 price 399.0 [3.] $  та мефурушад
# id= 7.0 price 399.0 [1.] $  та мефурушад
# id= 25.0 price 1099.0 [1.] $  та мефурушад
# id= 0.0 price 249.0 [1.] $  та мефурушад
# id= 11.0 price 1499.0 [1.] $  та мефурушад
# id= 24.0 price 2199.0 [1.] $  та мефурушад
# id= 3.0 price 149.0 [1.] $  та мефурушад
# id= 8.0 price 99.0 [1.] $  та мефурушад
# id= 11.0 price 2199.0 [1.] $  та мефурушад
# id= 28.0 price 99.0 [1.] $  та мефурушад
# id= 10.0 price 99.0 [1.] $  та мефурушад
# id= 30.0 price 349.0 [1.] $  та мефурушад
# id= 1.0 price 199.0 [1.] $  та мефурушад
# id= 32.0 price 229.0 [1.] $  та мефурушад
# id= 14.0 price 999.0 [1.] $  та мефурушад
# id= 5.0 price 299.0 [1.] $  та мефурушад
# id= 16.0 price 1699.0 [1.] $  та мефурушад
# id= 28.0 price 1199.0 [1.] $  та мефурушад
# id= 5.0 price 899.0 [1.] $  та мефурушад
# id= 11.0 price 2599.0 [1.] $  та мефурушад
# id= 3.0 price 999.0 [1.] $  та мефурушад
# id= 15.0 price 499.0 [1.] $  та мефурушад
# id= 17.0 price 599.0 [2.] $  та мефурушад
# id= 29.0 price 3999.0 [1.] $  та мефурушад
# id= 21.0 price 2389.5 [1.] $  та мефурушад
# id= 31.0 price 1099.0 [1.] $  та мефурушад
# id= 10.0 price 999.0 [1.] $  та мефурушад
# id= 21.0 price 99.0 [1.] $  та мефурушад
# id= 19.0 price 199.0 [1.] $  та мефурушад
# id= 9.0 price 899.0 [1.] $  та мефурушад
# id= 23.0 price 549.0 [1.] $  та мефурушад
# id= 24.0 price 4.8 [4.] $  та мефурушад
# id= 10.0 price 1979.0 [1.] $  та мефурушад
# id= 2.0 price 1999.0 [1.] $  та мефурушад
# id= 4.0 price 99.0 [1.] $  та мефурушад
# id= 24.0 price 999.0 [1.] $  та мефурушад
# id= 6.0 price 349.0 [3.] $  та мефурушад
# id= 18.0 price 399.0 [1.] $  та мефурушад
# id= 12.0 price 2599.0 [1.] $  та мефурушад
# id= 10.0 price 5.0 [30.] $  та мефурушад
# id= 17.0 price 199.0 [1.] $  та мефурушад
# id= 10.0 price 199.0 [1.] $  та мефурушад
# id= 22.0 price 399.0 [1.] $  та мефурушад

# %%
datas.head()
# Out:
#    date_block_num  shop_id  item_id  item_price
# 0               1       42    11919       149.0
# 1               4       50    17822       349.0
# 2              27       22     6789       498.0
# 3               4       54    11496       399.0
# 4               7       10    19415       399.0

# %%
{ col:[0] for col in X.columns}
# Out:
# {'date_block_num': [0], 'shop_id': [0], 'item_id': [0], 'item_price': [0]}

# %%
example = {'date_block_num': [3], 'shop_id': [10], 'item_id': [13643], 'item_price': [1199]}

# %%
example_df = pd.DataFrame(example)
example_df
# Out:
#    date_block_num  shop_id  item_id  item_price
# 0               3       10    13643        1199

# %%
rfc.predict(example_df)
# Out:
# array([1.])

# %%
df.shape
# Out:
# (2935849, 6)

# %%
datas.shape
# Out:
# (29358, 4)

# %%
datas[(datas['item_id'] == 13643)]
# Out:
#        date_block_num  shop_id  item_id  item_price
# 28614              23       31    13643      1199.0

# %%
x = df[df['item_id'] == 13643]

# %%
x
# Out:
#                date  date_block_num  shop_id  item_id  item_price  \
#