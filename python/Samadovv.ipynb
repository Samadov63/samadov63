# %%
import pandas as pd

airports = pd.read_csv(r'C:\Users\User2\Desktop\airports.csv')
airports
# Out:
#            id    ident            type                                name  \
# 0        6523      00A        heliport                   Total Rf Heliport
# 1      323361     00AA   small_airport                Aero B Ranch Airport
# 2        6524     00AK   small_airport                        Lowell Field
# 3        6525     00AL   small_airport                        Epps Airpark
# 4        6526     00AR          closed  Newport Hospital & Clinic Heliport
# ...       ...      ...             ...                                 ...
# 64148   32753     ZYYY  medium_airport             Shenyang Dongta Airport
# 64149   46378  ZZ-0001        heliport                     Sealand Helipad
# 64150  307326  ZZ-0002   small_airport           Glorioso Islands Airstrip
# 64151  342102     ZZZW          closed              Scandium City Heliport
# 64152  313629     ZZZZ   small_airport              Satsuma Iōjima Airport
#
# ...

# %%
airports1 = airports[(airports.scheduled_service=='no')].filter(items=['type', 'name', 'iso_country'])
airports1
# Out:
#                  type                                name iso_country
# 0            heliport                   Total Rf Heliport          US
# 1       small_airport                Aero B Ranch Airport          US
# 2       small_airport                        Lowell Field          US
# 3       small_airport                        Epps Airpark          US
# 4              closed  Newport Hospital & Clinic Heliport          US
# ...               ...                                 ...         ...
# 64148  medium_airport             Shenyang Dongta Airport          CN
# 64149        heliport                     Sealand Helipad          GB
# 64150   small_airport           Glorioso Islands Airstrip          TF
# 64151          closed              Scandium City Heliport          CA
# 64152   small_airport              Satsuma Iōjima Airport          JP
#
# [60029 rows x 3 columns]

# %%
airports1 = airports[(airports.scheduled_service!='no')].filter(items=['type', 'name', 'iso_country', 'continent'])
airports1
# Out:
#                  type                                     name iso_country  \
# 227     small_airport                           Utirik Airport          MH
# 240          heliport                     M.P. Metals Heliport          US
# 309          heliport   Russell County Medical Center Heliport          US
# 319     small_airport                    Wasilla Creek Airpark          US
# 326     small_airport                  Rancho De Aereo Airport          US
# ...               ...                                      ...         ...
# 64142   large_airport  Dalian Zhoushuizi International Airport          CN
# 64143  medium_airport                Tonghua Sanyuanpu Airport          CN
# 64144   large_airport   Shenyang Taoxian International Airport          CN
# 64146  medium_airport              Yanji Chaoyangchuan Airport          CN
# 64147  medium_airport                    Yingkou Lanqi Airport          CN
#
#       continent
# 227          OC
# 240         NaN
# ...

# %%
airports.query('iso_country == "US" & type == "heliport"')
# Out:
#            id ident      type                                  name  \
# 0        6523   00A  heliport                     Total Rf Heliport
# 9      322658  00CN  heliport       Kitchen Creek Helibase Heliport
# 12       6532  00FD  heliport                    Ringhaver Heliport
# 15       6535  00GE  heliport                      Caffrey Heliport
# 16       6536  00HI  heliport                    Kaupulehu Heliport
# ...       ...   ...       ...                                   ...
# 61676   26308  XS85  heliport     University Health System Heliport
# 61678   26310  XS87  heliport   Industrial Helicopters Inc Heliport
# 61687   26319  XS96  heliport                     Hillwood Heliport
# 61688   26320  XS97  heliport  Charlton Methodist Hospital Heliport
# 61689   26321  XS98  heliport           Guadalupe Hospital Heliport
#
#        latitude_deg  longitude_deg  elevation_ft continent iso_country  \
# 0         40.070801     -74.933601          11.0       NaN          US
# ...

# %%
airports.filter(like = '1000', axis = 0)
# Out:
#            id    ident            type  \
# 1000     7440     0OH2          closed
# 10000   15656      9B1          closed
# 10001   15657      9B8   small_airport
# 10002   15658      9C0   seaplane_base
# 10003   15660     9CA0   small_airport
# 10004   15661     9CA1        heliport
# 10005   15662     9CA2        heliport
# 10006   15663     9CA3        heliport
# 10007   15664     9CA4        heliport
# 10008   15665     9CA5        heliport
# 10009   15666     9CA6   small_airport
# 11000   38714  AR-0039   small_airport
# 21000  321046  ES-0114   small_airport
# 31000   19649     KDPG   small_airport
# 41000   22868     ND42   small_airport
# 51000   37083     SNFK          closed
# 61000   26848     WIOP  medium_airport
#
#                                               name  latitude_deg  \
# 1000                                 Jenkins Field     39.970604
# 10000                             Marlboro Airport     42.343201
# ...

# %%
pd.unique(airports.iso_country)
# Out:
# array(['US', 'PR', 'MH', 'MP', 'GU', 'SO', 'AQ', 'GB', 'PG', 'PH', 'AD',
#        'SD', 'SA', 'AE', 'SS', 'ES', 'CN', 'AF', 'LK', 'AG', 'SB', 'CO',
#        'AU', 'MG', 'AI', 'TD', 'AL', 'XK', 'AM', 'MX', 'MZ', 'PW', 'NR',
#        'AO', 'AR', 'AS', 'AT', 'AW', 'GA', 'AZ', 'BA', 'BD', 'BE', 'BF',
#        'BG', 'GL', 'BH', 'BI', 'IS', 'BJ', 'OM', 'BM', 'KE', 'BN', 'BO',
#        'BQ', 'BR', 'BS', 'BT', 'CV', 'BW', 'FJ', 'BY', 'UA', 'LR', 'BZ',
#        'CA', 'CD', 'CF', 'CG', 'MR', 'CH', 'CI', 'CL', 'CM', 'CR', 'CU',
#        'CY', 'CZ', 'SK', 'PA', 'DZ', 'YE', 'DE', 'ID', 'GH', 'RU', 'DJ',
#        'DK', 'NG', 'DO', 'NE', 'HR', 'TN', 'TG', 'EC', 'EE', 'FI', 'EG',
#        'GG', 'JE', 'IM', 'FK', 'EH', 'NL', 'IE', 'FO', 'LU', 'GT', 'NO',
#        'PL', 'ER', 'MN', 'PT', 'SE', 'ZW', 'ET', 'LV', 'LT', 'ZA', 'SZ',
#        'GQ', 'SH', 'MU', 'IO', 'ZM', 'FM', 'KM', 'YT', 'RE', 'TF', 'MV',
#        'ST', 'FR', 'SC', 'MW', 'LS', nan, 'ML', 'GM', 'GE', 'GF', 'SL',
# ...

# %%
airports[airports.continent.notnull()]
# Out:
#            id    ident            type                                 name  \
# 227      4650      03N   small_airport                       Utirik Airport
# 1128     4777     0TT8        heliport                     Dynasty Heliport
# 10247  328149     9OG1        heliport  Barrigada Readiness Center Heliport
# 10481  324756      AAD   small_airport                        Adado Airport
# 10482   30609     AAXX   small_airport                Rothera Point Airport
# ...       ...      ...             ...                                  ...
# 64147  317861     ZYYK  medium_airport                Yingkou Lanqi Airport
# 64148   32753     ZYYY  medium_airport              Shenyang Dongta Airport
# 64149   46378  ZZ-0001        heliport                      Sealand Helipad
# 64150  307326  ZZ-0002   small_airport            Glorioso Islands Airstrip
# 64152  313629     ZZZZ   small_airport               Satsuma Iōjima Airport
#
# ...

# %%
airports[airports ['iso_country']. str [0] == 'A']
# Out:
#            id    ident           type  \
# 10482   30609     AAXX  small_airport
# 10488  318235  AD-0001       heliport
# 10489  338490  AD-0002         closed
# 10490   41841   AD-ALV       heliport
# 10495   44426  AE-0002       heliport
# ...       ...      ...            ...
# 63545   27187     YYWG  small_airport
# 63546   28099     YZAN  small_airport
# 63547  324769     YZCE  small_airport
# 63548   28100     YZHN  small_airport
# 63838  315507      ZDY  small_airport
#
#                                                     name  latitude_deg  \
# 10482                              Rothera Point Airport    -67.566941
# 10488                          Terra Guindaldes Heliport     42.546257
# 10489              Arinsal (Coll de la Botella) Heliport     42.544983
# 10490  Andorra la Vella (Our Lady of Meritxell Hospit...     42.511174
# 10495                        Burj al Arab Resort Helipad     25.141327
# ...                                                  ...           ...
# ...

# %%
airports[airports ['iso_country']. str [-1] == 'A']
# Out:
#            id    ident            type                        name  \
# 10494   42257  AE-0001   small_airport               Batha Airport
# 11968  301838      AWE   small_airport               Alowe Airport
# 12367   43884  BA-0001   small_airport      Sport airfield Ciljuge
# 12368  317425  BA-0002   small_airport  Sportski Aerodrom Zalužani
# 12369  321737  BA-0003   small_airport               Brod Airstrip
# ...       ...      ...             ...                         ...
# 63868  342104     ZHIT          closed            Yukonia Airstrip
# 63876  342105     ZHZH  medium_airport       Herschel Island Field
# 63963  332195      ZNU   seaplane_base        Namu Water Aerodrome
# 64145  342103     ZYXW          closed           Mt Logan Airstrip
# 64151  342102     ZZZW          closed      Scandium City Heliport
#
#        latitude_deg  longitude_deg  elevation_ft continent iso_country  \
# 10494     24.214693      51.449890           NaN        AS          SA
# ...

# %%
airports[airports ['name']. str.contains ('A | B')]
# Out:
#            id ident            type                                      name  \
# 1      323361  00AA   small_airport                      Aero B Ranch Airport
# 36     321919  00NK   seaplane_base                 Cliche Cove Seaplane Base
# 40     328503  00OK   small_airport                  Gull Bay Landing Airport
# 45       6560   00S   small_airport             McKenzie Bridge State Airport
# 48       6562  00TA          closed                    SW Region FAA Heliport
# ...       ...   ...             ...                                       ...
# 64005   32649  ZSWU  medium_airport                             Wuhu Air Base
# 64018   30788  ZUBD  medium_airport                      Qamdo Bangda Airport
# 64119   30646  ZYAS  medium_airport  Anshan Teng'ao Airport / Anshan Air Base
# 64133   31706  ZYJZ   small_airport               Jinzhou Xiaolingzi Air Base
# 64135  300516  ZYLS  medium_airport                      Yushu Batang Airport
#
# ...

# %%
airports.agg({'elevation_ft': ['max', 'min', 'mean']})
# Out:
#       elevation_ft
# max   22000.000000
# min   -1266.000000
# mean   1265.040946

# %%
airports.drop(index=[1,2])
airports
# Out:
#            id    ident            type                                name  \
# 0        6523      00A        heliport                   Total Rf Heliport
# 1      323361     00AA   small_airport                Aero B Ranch Airport
# 2        6524     00AK   small_airport                        Lowell Field
# 3        6525     00AL   small_airport                        Epps Airpark
# 4        6526     00AR          closed  Newport Hospital & Clinic Heliport
# ...       ...      ...             ...                                 ...
# 64148   32753     ZYYY  medium_airport             Shenyang Dongta Airport
# 64149   46378  ZZ-0001        heliport                     Sealand Helipad
# 64150  307326  ZZ-0002   small_airport           Glorioso Islands Airstrip
# 64151  342102     ZZZW          closed              Scandium City Heliport
# 64152  313629     ZZZZ   small_airport              Satsuma Iōjima Airport
#
# ...
