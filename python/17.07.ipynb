# %%
import pandas as pd
df = pd.read_csv(r'C:\Users\HP\Desktop\sales_train.csv')

# %%
df.head()
# Out:
#          date  date_block_num  shop_id  item_id  item_price  item_cnt_day
# 0  02.01.2013               0       59    22154      999.00           1.0
# 1  03.01.2013               0       25     2552      899.00           1.0
# 2  05.01.2013               0       25     2552      899.00          -1.0
# 3  06.01.2013               0       25     2554     1709.05           1.0
# 4  15.01.2013               0       25     2555     1099.00           1.0

# %%
df.shape
# Out:
# (2935849, 6)

# %%
df.groupby('item_cnt_day').agg({'item_cnt_day': 'count'})
# Out:
#               item_cnt_day
# item_cnt_day
# -22.0                    1
# -16.0                    1
# -9.0                     1
# -6.0                     2
# -5.0                     4
# ...                    ...
#  624.0                   1
#  637.0                   1
#  669.0                   1
#  1000.0                  1
#  2169.0                  1
#
# [198 rows x 1 columns]

# %%
arr = df.sample(frac=0.1, replace=True, random_state=1)
arr = pd.DataFrame(arr)
arr.to_csv('file.csv')
data = pd.read_csv('file.csv')
data.head()
data.shape
data.drop('date', axis=1, inplace=True)

# %%
data.shape
# Out:
# (293585, 6)

# %%
data.drop('Unnamed: 0', axis=1, inplace=True)

# %%
X=data.drop('item_cnt_day', axis=1)
y = data['item_cnt_day']
from sklearn.ensemble import RandomForestClassifier

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)
rfc=RandomForestClassifier().fit(X_train,y_train)
rfc.score(X_test,y_test)
# Out:
# 0.8864383398334383

# %%
data.head()
data.shape
# Out:
# (293585, 6)

# %%
data.head()
# Out:
#    Unnamed: 0  date_block_num  shop_id  item_id  item_price  item_cnt_day
# 0      128037               1       42    11919       149.0           1.0
# 1      491755               4       50    17822       349.0           2.0
# 2     2568076              27       22     6789       498.0           1.0
# 3      491263               4       54    11496       399.0           3.0
# 4      836489               7       10    19415       399.0           1.0

# %%
# rfc.predict([[4, 50, 17822, 349.0]])


datas = data.drop('item_cnt_day', axis=1)

# %%
# from sklearn.linear_model import LogisticRegression
# from sklearn.naive_bayes import GaussianNB
# from sklearn.svm import SVC
# from sklearn.ensemble import VotingClassifier
# model1 = LogisticRegression(random_state=1, solver='newton-cg')
# model2 = DecisionTreeClassifier(random_state=1)
# model3=GaussianNB()
# model4=SVC()
# model = VotingClassifier(estimators=[('lr', model1), ('dt', model2),('gnb',model3),('svc', model4)], voting='hard')
# model.fit(X_train,y_train)
# model.score(X_test,y_test)

# %%
# rfc.predict()
import numpy as np
arr = np.array(datas)

# %%
arr[1]
# Out:
# array([4.91755e+05, 4.00000e+00, 5.00000e+01, 1.78220e+04, 3.49000e+02])

# %%
rfc.predict(arr[[3]])
# Out:
# array([3.])

# %%
c = 0
for i in arr:
    print('id=', i[0], 'price', i[-1], rfc.predict([i]), '$ ','та мефурушад')
    c += 1
    if c == 100:
        break
# Out:
# id= 128037.0 price 149.0 [1.] $  та мефурушад
# id= 491755.0 price 349.0 [2.] $  та мефурушад
# id= 2568076.0 price 498.0 [1.] $  та мефурушад
# id= 491263.0 price 399.0 [3.] $  та мефурушад
# id= 836489.0 price 399.0 [1.] $  та мефурушад
# id= 2468555.0 price 1099.0 [1.] $  та мефурушад
# id= 73349.0 price 249.0 [1.] $  та мефурушад
# id= 1166159.0 price 1499.0 [1.] $  та мефурушад
# id= 2326672.0 price 2199.0 [1.] $  та мефурушад
# id= 413825.0 price 149.0 [1.] $  та мефурушад
# id= 925255.0 price 99.0 [1.] $  та мефурушад
# id= 1215878.0 price 2199.0 [1.] $  та мефурушад
# id= 2610452.0 price 99.0 [1.] $  та мефурушад
# id= 1070334.0 price 99.0 [1.] $  та мефурушад
# id= 2788242.0 price 899.5 [1.] $  та мефурушад
# id= 575956.0 price 599.0 [2.] $  та мефурушад
# id= 1506187.0 price 399.0 [1.] $  та мефурушад
# id= 401660.0 price 199.0 [1.] $  та мефурушад
# id= 806378.0 price 449.5 [1.] $  та мефурушад
# id= 365212.0 price 1299.0 [1.] $  та мефурушад
# ...

# %%
datas.head()
# Out:
#    Unnamed: 0  date_block_num  shop_id  item_id  item_price
# 0      128037               1       42    11919       149.0
# 1      491755               4       50    17822       349.0
# 2     2568076              27       22     6789       498.0
# 3      491263               4       54    11496       399.0
# 4      836489               7       10    19415       399.0

# %%
{ col:[0] for col in X.columns}
# Out:
# {'Unnamed: 0': [0],
#  'date_block_num': [0],
#  'shop_id': [0],
#  'item_id': [0],
#  'item_price': [0]}

# %%
example = {'date_block_num': [3], 'shop_id': [10], 'item_id': [13643], 'item_price': [1199.0]}

# %%
example_df = pd.DataFrame(example)
example_df
# Out:
#    date_block_num  shop_id  item_id  item_price
# 0               3       10    13643      1199.0

# %%
rfc.predict(example_df)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-27-4020347dfc60> in <module>
# ----> 1 rfc.predict(example_df)
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\_forest.py in predict(self, X)
#     627             The predicted classes.
#     628         """
# --> 629         proba = self.predict_proba(X)
#     630
#     631         if self.n_outputs_ == 1:
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\_forest.py in predict_proba(self, X)
#     671         check_is_fitted(self)
#     672         # Check data
# --> 673         X = self._validate_X_predict(X)
#     674
#     675         # Assign chunk of trees to jobs
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\_forest.py in _validate_X_predict(self, X)
#     419         check_is_fitted(self)
#     420
# ...

# %%
df.shape

# %%
datas.shape
# Out:
# (293585, 5)

# %%
datas[(datas['item_id'] == 13643)]
# Out:
#        date_block_num  shop_id  item_id  item_price
# 28614              23       31    13643      1199.0

# %%
x = df[df['item_id'] == 13643]

# %%
x
# Out:
#                date  date_block_num  shop_id  item_id  item_price  \
# 2194481  27.12.2014              23       42    13643      1199.0
# 2194482  30.12.2014              23       42    13643      1199.0
# 2194531  21.12.2014              23       42    13643      1199.0
# 2194543  20.12.2014              23       42    13643      1199.0
# 2194616  19.12.2014              23       42    13643      1199.0
# 2199195  24.12.2014              23       43    13643      1199.0
# 2199196  22.12.2014              23       43    13643      1199.0
# 2199197  13.12.2014              23       43    13643      1199.0
# 2212863  31.12.2014              23       57    13643      1199.0
# 2225308  31.12.2014              23       31    13643      1199.0
# 2225309  29.12.2014              23       31    13643      1199.0
# 2225310  11.12.2014              23       31    13643      1199.0
# 2247890  30.12.2014              23       40    13643      1199.0
# ...

# %%
x.groupby('item_cnt_day').agg({'item_cnt_day': 'count'})
# Out:
#               item_cnt_day
# item_cnt_day
# 1.0                     36
# 2.0                      7
