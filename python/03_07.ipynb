# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
d = pd.read_csv(r'C:\Users\HP\Downloads\Telegram Desktop\countries (2).csv')
d.head()
# Out:
#        id code                  name continent  \
# 0  302672   AD               Andorra        EU
# 1  302618   AE  United Arab Emirates        AS
# 2  302619   AF           Afghanistan        AS
# 3  302722   AG   Antigua and Barbuda       NaN
# 4  302723   AI              Anguilla       NaN
#
#                                       wikipedia_link  \
# 0              https://en.wikipedia.org/wiki/Andorra
# 1  https://en.wikipedia.org/wiki/United_Arab_Emir...
# 2          https://en.wikipedia.org/wiki/Afghanistan
# 3  https://en.wikipedia.org/wiki/Antigua_and_Barbuda
# 4             https://en.wikipedia.org/wiki/Anguilla
#
#                                  keywords
# 0                                     NaN
# 1  UAE,مطارات في الإمارات العربية المتحدة
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN

# %%
d.fillna({'keywords': 0})
# Out:
#          id code                           name continent  \
# 0    302672   AD                        Andorra        EU
# 1    302618   AE           United Arab Emirates        AS
# 2    302619   AF                    Afghanistan        AS
# 3    302722   AG            Antigua and Barbuda       NaN
# 4    302723   AI                       Anguilla       NaN
# ..      ...  ...                            ...       ...
# 242  302609   YT                        Mayotte        AF
# 243  302610   ZA                   South Africa        AF
# 244  302611   ZM                         Zambia        AF
# 245  302612   ZW                       Zimbabwe        AF
# 246  302613   ZZ  Unknown or unassigned country        AF
#
#                                         wikipedia_link  \
# 0                https://en.wikipedia.org/wiki/Andorra
# 1    https://en.wikipedia.org/wiki/United_Arab_Emir...
# 2            https://en.wikipedia.org/wiki/Afghanistan
# ...

# %%
df = pd.read_excel('/content/Данные для TajRupt .xlsx')

# %%
df.head()
# Out:
#       id  Gender  ...  CNT_OF_ICOUPONPLUS_PAYMENTS  CH_OF_ICOUPONPLUS_PAYMENTS
# 0  16154       1  ...                            0                         0.0
# 1  16292       1  ...                            0                         0.0
# 2  13344       1  ...                            0                         0.0
# 3  16496       1  ...                            0                         0.0
# 4  33670       1  ...                            0                         0.0
#
# [5 rows x 23 columns]

# %%
df.describe()
# Out:
#                   id  ...  CH_OF_ICOUPONPLUS_PAYMENTS
# count   12156.000000  ...                12156.000000
# mean   246961.075107  ...                    0.001032
# std    143567.768174  ...                    0.113737
# min       100.000000  ...                    0.000000
# 25%    117573.500000  ...                    0.000000
# 50%    259853.500000  ...                    0.000000
# 75%    374631.500000  ...                    0.000000
# max    471662.000000  ...                   12.540000
#
# [8 rows x 19 columns]

# %%
df['Age'].hist()

# %%
df.shape
# Out:
# (12156, 23)

# %%
df.drop(columns=['CityNameLatin'], inplace=True)

# %%
df.head()
# Out:
#       id  Gender  ...  CNT_OF_ICOUPONPLUS_PAYMENTS  CH_OF_ICOUPONPLUS_PAYMENTS
# 0  16154       1  ...                            0                         0.0
# 1  16292       1  ...                            0                         0.0
# 2  13344       1  ...                            0                         0.0
# 3  16496       1  ...                            0                         0.0
# 4  33670       1  ...                            0                         0.0
#
# [5 rows x 22 columns]

# %%
df['device_name'].unique()
# Out:
# array([nan, 'iPhone X', 'Xiaomi Redmi Note 6 Pro', 'iPhone 7',
#        'samsung SM-A520F', 'Xiaomi Redmi 7', 'samsung SM-G960F',
#        'Xiaomi Redmi Note 8 Pro', 'Xiaomi M2004J19C', 'samsung SM-A525F',
#        'samsung SM-A705FN', 'iPhone 11 Pro', 'samsung SM-A315F',
#        'samsung SM-A305FN', 'samsung SM-T515', 'samsung SM-G900F',
#        'samsung SM-G950F', 'samsung SM-J500H', 'Xiaomi Redmi Note 8T',
#        'samsung SM-A505FN', 'samsung SM-A530F', 'samsung SM-G973U1',
#        'samsung SM-A715F', 'samsung SM-G965F', 'samsung SM-A217F',
#        'samsung SM-G973F', 'samsung SM-A515F', 'samsung SM-A730F',
#        'samsung SM-A307FN', 'Xiaomi Redmi Note 5', 'samsung SM-G800H',
#        'HUAWEI ANE-LX1', 'Xiaomi Redmi Note 7', 'samsung SM-A720F',
#        'Xiaomi Mi A3', 'Apple iPhone13,4', 'iPhone 11 Pro Max',
#        'samsung SM-A320F', 'Xiaomi Redmi Note 8',
#        'Xiaomi Mi Note 10 Lite', 'iPhone XR', 'Xiaomi Redmi 6 Pro',
# ...

# %%
df.shape
# Out:
# (12156, 22)

# %%
df[(df['CNT_OF_MOBILE_PAYMENTS'] > 0)]
# Out:
#            id  Gender  ...  CNT_OF_ICOUPONPLUS_PAYMENTS  CH_OF_ICOUPONPLUS_PAYMENTS
# 11      15681       1  ...                            0                         0.0
# 15      14672       1  ...                            0                         0.0
# 18      16141       1  ...                            0                         0.0
# 37      15037       1  ...                            0                         0.0
# 54      16049       1  ...                            0                         0.0
# ...       ...     ...  ...                          ...                         ...
# 12003  407394       0  ...                            0                         0.0
# 12013  442246       1  ...                            0                         0.0
# 12072  437111       1  ...                            0                         0.0
# 12135  441748       1  ...                            0                         0.0
# ...

# %%
df['CNT_OF_MOBILE_PAYMENTS'].max()
# Out:
# 71

# %%
#Подготовка данных

# %%
pd.get_dummies(df, columns= ['Tarif', 'device_name', 'CellId2'])
# Out:
#            id  Gender  Age  ...  CellId2_ff2b  CellId2_ff34  CellId2_ff35
# 0       16154       1   28  ...             0             0             0
# 1       16292       1   37  ...             0             0             0
# 2       13344       1   40  ...             0             0             0
# 3       16496       1   32  ...             0             0             0
# 4       33670       1   31  ...             0             0             0
# ...       ...     ...  ...  ...           ...           ...           ...
# 12151  397326       1   28  ...             0             0             0
# 12152  450002       1   27  ...             0             0             0
# 12153  466251       0   48  ...             0             0             0
# 12154  461116       1   29  ...             0             0             0
# 12155  458700       1   41  ...             0             0             0
#
# [12156 rows x 4445 columns]

# %%
df['Tarif'].unique()
# Out:
# array(['Фаъол', 'Дастрас', 'Активный +', 'Сугдиен', 'Оддӣ', 'Муфид',
#        'Махсус', 'Фоиданок', 'Бобарор', 'Тоҷирон', 'Успешный +',
#        'Активный Экстра +', 'Кайҳон 3', '4G_LTE', 'Сайёх',
#        'Дастрас Базовый', 'Суҳбаторо', 'Кайҳон 2', '3G MobiNet',
#        'Особый +', 'Кайҳон 1', 'Успешный Экстра +', 'Кайҳон 4', 'Эконом',
#        'ДастрасNew', 'Основной', 'Гуфтугӯ 2', 'M2M', 'Ҷавонон',
#        '3G Mobinet - 1000', 'Гуфтугӯ 3', 'Бемалол 5', 'Особый Экстра +',
#        'Гуфтугӯ 4', 'Бизнесмен Экстра +', 'Активный (Фаъол)', 'Бемалол',
#        'Бизнесмен +', 'Сухбаторо', 'Обычный +', 'Гуфтугу1',
#        'Специальный UNDP', 'Гуфтугӯ 1', 'Бизнесмен (Точирон)', 'Кайҳон 5',
#        'Выгодный (Фоиданок)', 'Mobinet-Service1', '3G Mobinet - 3000',
#        'Обычный Экстра +', 'Основной+', 'Special tariff 1',
#        'Специальный USA Embassy', 'Базовый ЭкстраNew'], dtype=object)

# %%
a=df['Tarif'].map({
    'Фаъол':1,
    'Дастрас':2
})

# %%
df=df.assign(y=pd.Series(a))

# %%
df.head()
# Out:
#       id  Gender  ...  CH_OF_ICOUPONPLUS_PAYMENTS    y
# 0  16154       1  ...                         0.0  1.0
# 1  16292       1  ...                         0.0  1.0
# 2  13344       1  ...                         0.0  1.0
# 3  16496       1  ...                         0.0  2.0
# 4  33670       1  ...                         0.0  1.0
#
# [5 rows x 23 columns]

# %%
 if df[df['CNT_OF_MOBILE_PAYMENTS']> 0]:

# %%
df['CNT_OF_MOBILE_PAYMENTS'].unique()
# Out:
# array([ 0, 39,  1,  3,  5,  4,  2,  9,  7,  8, 28, 11, 13,  6, 10, 18, 14,
#        12, 29, 19, 47, 31, 24, 15, 21, 71, 20, 25, 17])

# %%
df.corr()
# Out:
#                                       id  ...         y
# id                              1.000000  ... -0.090581
# Gender                         -0.023504  ... -0.031072
# Age                            -0.010688  ...  0.062205
# ARPU                            0.013706  ...  0.142794
# CNT_OF_AUTHORIZATIONS           0.002125  ... -0.045156
# CNT_OF_MOBILE_PAYMENTS          0.000445  ... -0.018750
# CH_OF_MOBILE_PAYMENTS          -0.003277  ... -0.024328
# CNT_OF_PUBLIC_SERVICE_PAYMENTS -0.015565  ... -0.010081
# CH_OF_PUBLIC_SERVICE_PAYMENTS  -0.028117  ...  0.003084
# CNT_OF_BANK_PAYMENTS           -0.017664  ... -0.008836
# CH_OF_BANK_PAYMENTS            -0.017488  ... -0.018322
# CNT_OF_INTERNET_PAYMENTS       -0.025110  ... -0.019132
# CH_OF_INTERNET_PAYMENTS        -0.031502  ... -0.023166
# CNT_OF_QR_PAYMENTS              0.005730  ... -0.021022
# CH_OF_QR_PAYMENTS               0.010413  ... -0.025791
# CNT_OF_EOMMERCE_PAYMENTS       -0.014719  ... -0.008817
# ...

# %%
a=[39,  1,  3,  5,  4,  2,  9,  7,  8, 28, 11, 13,  6, 10, 18, 14,12, 29, 19, 47, 31, 24, 15, 21, 71, 20, 25, 17]
a=df['CNT_OF_MOBILE_PAYMENTS'].replace(a,1)
a.unique()
# Out:
# array([0, 1])

# %%
df=df.assign(y=pd.Series(a))

# %%
y=df['y']
X = df.drop(columns=['y','CNT_OF_MOBILE_PAYMENTS','CH_OF_MOBILE_PAYMENTS','CellId2','id'],axis=1)

# %%
X.columns
# Out:
# Index(['Gender', 'Age', 'ARPU', 'Tarif', 'CNT_OF_AUTHORIZATIONS',
#        'device_name', 'CNT_OF_PUBLIC_SERVICE_PAYMENTS',
#        'CH_OF_PUBLIC_SERVICE_PAYMENTS', 'CNT_OF_BANK_PAYMENTS',
#        'CH_OF_BANK_PAYMENTS', 'CNT_OF_INTERNET_PAYMENTS',
#        'CH_OF_INTERNET_PAYMENTS', 'CNT_OF_QR_PAYMENTS', 'CH_OF_QR_PAYMENTS',
#        'CNT_OF_EOMMERCE_PAYMENTS', 'CH_OF_ECOMMERCE_PAYMENTS',
#        'CNT_OF_ICOUPONPLUS_PAYMENTS', 'CH_OF_ICOUPONPLUS_PAYMENTS'],
#       dtype='object')

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=0)

# %%
y_train.shape
# Out:
# (9724,)

# %%
X_test.shape
# Out:
# (2432, 18)

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dtree=DecisionTreeClassifier()

# %%
dtree.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-68-16b736c34381> in <module>()
# ----> 1 dtree.fit(X_train, y_train)
#
# /usr/local/lib/python3.7/dist-packages/sklearn/tree/_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     875             sample_weight=sample_weight,
#     876             check_input=check_input,
# --> 877             X_idx_sorted=X_idx_sorted)
#     878         return self
#     879
#
# /usr/local/lib/python3.7/dist-packages/sklearn/tree/_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     147
#     148         if check_input:
# --> 149             X = check_array(X, dtype=DTYPE, accept_sparse="csc")
#     150             y = check_array(y, ensure_2d=False, dtype=None)
#     151             if issparse(X):
#
# ...

# %%
df = df.astype({'CH_OF_MOBILE_PAYMENTS': 'float'})

# %%
df
# Out:
#            id  Gender  ...  CH_OF_ICOUPONPLUS_PAYMENTS  y
# 0       16154       1  ...                         0.0  0
# 1       16292       1  ...                         0.0  0
# 2       13344       1  ...                         0.0  0
# 3       16496       1  ...                         0.0  0
# 4       33670       1  ...                         0.0  0
# ...       ...     ...  ...                         ... ..
# 12151  397326       1  ...                         0.0  0
# 12152  450002       1  ...                         0.0  0
# 12153  466251       0  ...                         0.0  0
# 12154  461116       1  ...                         0.0  0
# 12155  458700       1  ...                         0.0  0
#
# [12156 rows x 23 columns]

# %%
df.dtypes
# Out:
# id                                  int64
# Gender                              int64
# Age                                 int64
# ARPU                                int64
# CellId2                            object
# Tarif                              object
# CNT_OF_AUTHORIZATIONS               int64
# device_name                        object
# CNT_OF_MOBILE_PAYMENTS              int64
# CH_OF_MOBILE_PAYMENTS             float64
# CNT_OF_PUBLIC_SERVICE_PAYMENTS      int64
# CH_OF_PUBLIC_SERVICE_PAYMENTS     float64
# CNT_OF_BANK_PAYMENTS                int64
# CH_OF_BANK_PAYMENTS               float64
# CNT_OF_INTERNET_PAYMENTS            int64
# CH_OF_INTERNET_PAYMENTS             int64
# CNT_OF_QR_PAYMENTS                  int64
# CH_OF_QR_PAYMENTS                 float64
# CNT_OF_EOMMERCE_PAYMENTS            int64
# CH_OF_ECOMMERCE_PAYMENTS            int64
# CNT_OF_ICOUPONPLUS_PAYMENTS         int64
# CH_OF_ICOUPONPLUS_PAYMENTS        float64
# ...

# %%
Оценка

# %%
from sklearn.metrics import classification_report,confusion_matrix

# %%
print(classification_report(y_test,predict))

# %%
print(confusion_matrix(y_test,predict))

# %%
Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rfc=RandomForestClassifier()

# %%
rfc.fit(X_train,y_train)

# %%
predict=rfc.predict(X_test)

# %%
Оценка модели

# %%
print(classification_report(y_test,predict))

# %%
print(confusion_matrix(y_test,predict))

# %%
from sklearn import linear_model
LR=linear_model.LogisticRegression(random_state=0)
LR.fit(X_train,y_train)
predict=LR.predict(X_test)
